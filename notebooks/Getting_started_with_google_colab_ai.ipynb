# %% [markdown]
# <a href="https://colab.research.google.com/github/abod73/Alexbot/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
import os

# Clone the repository
# !git clone https://github.com/acc714710-star/hhajaj.git

# Change into the project directory
os.chdir('hhajaj')
# Out:
# Cloning into 'hhajaj'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 82 (delta 34), reused 32 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (82/82), 184.03 KiB | 2.27 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# The previous installation attempt failed.
# Let's inspect the contents of the cloned repository to understand its structure.
# !ls -F
# Out:
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %% [markdown]
# The project should now be installed. You can now import modules from the `hhajaj` package.
